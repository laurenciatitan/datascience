# %% [markdown]
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint
import pandas as pd
import numpy as np
import time
import copy

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
import time
player_id= 1
player_name ='laurencia'
time_played = '0.0'
player_pokemon ={} 
gyms_visited =[]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gymlocation = ['reddit.com', 'twitter.com','linkedin.com','ebay.com',
'netflix.com', 'amazon.com','stackoverflow.com','github.com','quora.com']
print (gymlocation)
# Out:
# ['reddit.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'amazon.com', 'stackoverflow.com', 'github.com', 'quora.com']

# %%
gym_visited =gymlocation[0:2]
print (gym_visited)
# Out:
# ['reddit.com', 'twitter.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex ={
     1: {'name':'charmander',
         'type':'fire', 
         'hp': 100, 
         'attack': 100, 
         'defense': 100, 
         'special attack': 1000,
         'special defence' : 1000,
         'speed':10
        },
     2: {'name': 'squirtle',
         'type' :'water',
         'hp': 99, 
         'attack': 99, 
         'defense': 99, 
         'special attack': 9999,
         'special defence' : 9999,
         'speed':99
        },
     3: {'name': 'bulbasaur',
        'type' :'poison',
         'hp': 88, 
         'attack': 88, 
         'defense': 8888, 
         'special attack': 8888,
         'special defence' : 8888,
         'speed':88
        }
}
pokedex
# Out:
# {1: {'attack': 100,
#   'defense': 100,
#   'hp': 100,
#   'name': 'charmander',
#   'special attack': 1000,
#   'special defence': 1000,
#   'speed': 10,
#   'type': 'fire'},
#  2: {'attack': 99,
#   'defense': 99,
#   'hp': 99,
#   'name': 'squirtle',
#   'special attack': 9999,
#   'special defence': 9999,
#   'speed': 99,
#   'type': 'water'},
#  3: {'attack': 88,
#   'defense': 8888,
#   'hp': 88,
#   'name': 'bulbasaur',
#   'special attack': 8888,
#   'special defence': 8888,
#   'speed': 88,
#   'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %% [markdown]
# players ={
#      1: {'player_name':'laurencia',
#          'time_played': '12.14',
#          'player_pokemon': list(pokedex.keys())[0], #convert object to list
#          'gyms_visited': gymlocation[0:2]},
#      2: {'player_name':'cia',
#          'time_played': '22.22',
#          'player_pokemon': pokedex.values()[1], #get the value of pokedex
#          'gyms_visited': gymlocation[1:2]},
#      3 : {'player_name':'titan',
#          'time_played': '22.24',
#          'player_pokemon': {1:pokedex.values()[2]},
#           'gyms_visited': gymlocation[1:2]},
#      4: {'player_name':'cia',
#          'time_played': '22.22',
#          'player_pokemon': '', #get the value of pokedex
#          'gyms_visited': gymlocation[2:8]},
# }
# players[3]
#     # player 3= create new dictiionary (key[1], can put anything other than 1: value pokedex.values()[2])

# %%
players ={
     1: {'player_name':'laurencia', 
         'time_played': '12.14', 
         'player_pokemon': {pokedex.keys()[1]:pokedex.values()[1]}, #convert object to list
         'gyms_visited': gymlocation[0:2]},
     2: {'player_name':'cia',
         'time_played': '22.22', 
         'player_pokemon': {pokedex.keys()[2]:pokedex.values()[2]}, #get the value of pokedex
         'gyms_visited': gymlocation[1:2]},
     3 : {'player_name':'titan',
         'time_played': '22.24', 
         'player_pokemon': {pokedex.keys()[0]:pokedex.values()[0]}, 
          'gyms_visited': gymlocation[1:2]},
    4: {'player_name':'cia',
         'time_played': '22.22', 
         'player_pokemon': {pokedex.keys()[2]:pokedex.values()[2]}, #get the value of pokedex
         'gyms_visited': gymlocation[2:8]},
    
}
players

# player 3= create new dictiionary (key[1], can put anything other than 1: value pokedex.values()[2])
# Out:
# {1: {'gyms_visited': ['reddit.com', 'twitter.com'],
#   'player_name': 'laurencia',
#   'player_pokemon': {2: {'attack': 99,
#     'defense': 99,
#     'hp': 99,
#     'name': 'squirtle',
#     'special attack': 9999,
#     'special defence': 9999,
#     'speed': 99,
#     'type': 'water'}},
#   'time_played': '12.14'},
#  2: {'gyms_visited': ['twitter.com'],
#   'player_name': 'cia',
#   'player_pokemon': {3: {'attack': 88,
#     'defense': 8888,
#     'hp': 88,
#     'name': 'bulbasaur',
#     'special attack': 8888,
#     'special defence': 8888,
#     'speed': 88,
#     'type': 'poison'}},
#   'time_played': '22.22'},
#  3: {'gyms_visited': ['twitter.com'],
#   'player_name': 'titan',
#   'player_pokemon': {1: {'attack': 100,
#     'defense': 100,
#     'hp': 100,
#     'name': 'charmander',
#     'special attack': 1000,
#     'special defence': 1000,
#     'speed': 10,
#     'type': 'fire'}},
#   'time_played': '22.24'},
#  4: {'gyms_visited': ['linkedin.com',
#    'ebay.com',
# ...

# %% [markdown]
# players ={
#      1: {'player_name':'laurencia',
#          'time_played': '12.14',
#          'player_pokemon': list(pokedex.keys())[0], #convert object to list
#          'gyms_visited': gymlocation[0:2]},
#      2: {'player_name':'cia',
#          'time_played': '22.22',
#          'player_pokemon': pokedex.values()[1], #get the value of pokedex
#          'gyms_visited': gymlocation[1:2]},
#      3 : {'player_name':'titan',
#          'time_played': '22.24',
#          'player_pokemon': {1:pokedex.values()[2]},
#           'gyms_visited': gymlocation[1:2]},
#      4: {'player_name':'cia',
#          'time_played': '22.22',
#          'player_pokemon': '', #get the value of pokedex
#          'gyms_visited': gymlocation[2:8]},
# }
# players[3]
#     # player 3= create new dictiionary (key[1], can put anything other than 1: value pokedex.values()[2])
#
# #players.update

# %%
---

### 4.2

Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.

The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.

Remember, the player_id is the key for the player in the players dictionary.

Print the `players` dictionary with the new player inserted.
# Out:
#   File "<ipython-input-10-49a64c478f5d>", line 1
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
import copy #learn from aesya
addition_gym_location = copy.copy(gymlocation)
addition_gym_location.append('alcatraz.com')
addition_gym_location.append('pacific_beach.com')
#addition_gym_location.append(('pacific_beach.com','alcatraz.com'))
print (addition_gym_location[9:12])

#players[2]['gyms_visited']['2']= gymlocation[1]
# Out:
# ['alcatraz.com', 'pacific_beach.com']

# %%
#add new players
#players[1].pokedex = {}
players[5] ={'player_name':'cia',
         'time_played': '22.22', 
         'player_pokemon': {pokedex.keys()[0]:pokedex.values()[0]}, #get the value of pokedex
         'gyms_visited': gymlocation[4:8]}
         
players
# Out:
# {1: {'gyms_visited': ['reddit.com', 'twitter.com'],
#   'player_name': 'laurencia',
#   'player_pokemon': {2: {'attack': 99,
#     'defense': 99,
#     'hp': 99,
#     'name': 'squirtle',
#     'special attack': 9999,
#     'special defence': 9999,
#     'speed': 99,
#     'type': 'water'}},
#   'time_played': '12.14'},
#  2: {'gyms_visited': ['twitter.com'],
#   'player_name': 'cia',
#   'player_pokemon': {3: {'attack': 88,
#     'defense': 8888,
#     'hp': 88,
#     'name': 'bulbasaur',
#     'special attack': 8888,
#     'special defence': 8888,
#     'speed': 88,
#     'type': 'poison'}},
#   'time_played': '22.22'},
#  3: {'gyms_visited': ['twitter.com'],
#   'player_name': 'titan',
#   'player_pokemon': {1: {'attack': 100,
#     'defense': 100,
#     'hp': 100,
#     'name': 'charmander',
#     'special attack': 1000,
#     'special defence': 1000,
#     'speed': 10,
#     'type': 'fire'}},
#   'time_played': '22.24'},
#  4: {'gyms_visited': ['linkedin.com',
#    'ebay.com',
# ...

# %% [markdown]
# players ={
#     1: {'player_name':'laurencia',
#          'time_played': '12:14',
#          'player_pokemon': pokedex[1]
#          }
# players

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.
# #https://www.programiz.com/python-programming/nested-dictionary

# %%
#1 : 'charmander'
#2 : 'squirtle'
#3 : 'bulbasaur'
players[2]
# Out:
# {'gyms_visited': ['twitter.com'],
#  'player_name': 'cia',
#  'player_pokemon': {3: {'attack': 88,
#    'defense': 8888,
#    'hp': 88,
#    'name': 'bulbasaur',
#    'special attack': 8888,
#    'special defence': 8888,
#    'speed': 88,
#    'type': 'poison'}},
#  'time_played': '22.22'}

# %%
#players[1]['player_pokemon']['2']= pokedex[1]
#players[2]['player_pokemon']['2']= pokedex[0]
#players[5]['player_pokemon'][2]= {pokedex.keys()[1]:pokedex.values()[1]}
players[5]['player_pokemon'][2]= pokedex.values()[1]
players[5]['player_pokemon'][2]= pokedex.values()[2]

# %%
players[5]
# Out:
# {'gyms_visited': ['netflix.com',
#   'amazon.com',
#   'stackoverflow.com',
#   'github.com'],
#  'player_name': 'cia',
#  'player_pokemon': {1: {'attack': 100,
#    'defense': 100,
#    'hp': 100,
#    'name': 'charmander',
#    'special attack': 1000,
#    'special defence': 1000,
#    'speed': 10,
#    'type': 'fire'},
#   2: {'attack': 88,
#    'defense': 8888,
#    'hp': 88,
#    'name': 'bulbasaur',
#    'special attack': 8888,
#    'special defence': 8888,
#    'speed': 88,
#    'type': 'poison'}},
#  'time_played': '22.22'}

# %% [markdown]
# def power (players, pokedex, pid):
#     for key in players.keys():
#         print (players[key]['player_pokemon'])
#
#     return power
# print(power(players, pokedex, 1))

# %% [markdown]
# for a in players:
#     for b in players[a]:
#         for c in players [b]:

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.
#
# #https://developers.google.com/edu/python/dict-files

# %%
loop= 0
#go through gymlocations
for eachlocation in gymlocation:
    #go through players key or id
    for playerid in players.keys():
        #comparing eachlocation value == players [gym_visited]
        # players[key]:[gym vsited] [playerid is temporaty id to get the key in players] key:value
        loop+=1
        if eachlocation in players[playerid]['gyms_visited']: 
            #if they are same get the players with location they have visited
            print('player:', playerid, 'gym visited:', eachlocation)
print(loop)
# Out:
# ('player:', 1, 'gym visited:', 'reddit.com')
# ('player:', 1, 'gym visited:', 'twitter.com')
# ('player:', 2, 'gym visited:', 'twitter.com')
# ('player:', 3, 'gym visited:', 'twitter.com')
# ('player:', 4, 'gym visited:', 'linkedin.com')
# ('player:', 4, 'gym visited:', 'ebay.com')
# ('player:', 4, 'gym visited:', 'netflix.com')
# ('player:', 5, 'gym visited:', 'netflix.com')
# ('player:', 4, 'gym visited:', 'amazon.com')
# ('player:', 5, 'gym visited:', 'amazon.com')
# ('player:', 4, 'gym visited:', 'stackoverflow.com')
# ('player:', 5, 'gym visited:', 'stackoverflow.com')
# ('player:', 4, 'gym visited:', 'github.com')
# ('player:', 5, 'gym visited:', 'github.com')
# 45

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# check on gymslocation and players
# #2^2 =4
# gym= 10 gymlocation *5 players

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.
#
# https://www.coursera.org/lecture/python-analysis/tabular-data-as-a-nested-dictionary-8hjvq

# %% [markdown]
# for pokeid, pokeinfo in pokedex.items():
#     for key in pokeinfo:
#         print(pokeid,key,pokeinfo[key])
# #get the key and value from nested dictionary

# %%
def power (players, pokedex, playerid):

    player_dictionary =players [playerid]['player_pokemon']
#look like this {'p1': 'squirtle', 'p2': 'charmander', 'p3': 'bulbasaur'}
    pokemon_list = list(player_dictionary.values())
#look like this ['charmander', 'bulbasaur', 'squirtle']
    attack =0
    defense =0
    totalpower= 0
    
    for pokemon in pokemon_list:
        #iterate through player :player_pokemon list
        for pokedex_id in pokedex:
            #iterate through pokedex dictionary
            if pokemon['name'] == pokedex[pokedex_id]['name']:
                if pokemon['name'] in pokedex[pokedex_id]['name']:
                #compare id value is same
               
                    attack += pokedex[pokedex_id]['attack']
                    defense += pokedex[pokedex_id]['defense']
              
                    totalpower += pokedex[pokedex_id]['attack']
                    totalpower += pokedex[pokedex_id]['defense']
                    totalpower += pokedex[pokedex_id]['hp']
                    totalpower += pokedex[pokedex_id]['special attack']
                    totalpower += pokedex[pokedex_id]['special defence']
                
                
                
    print(players[playerid]['player_name'], 'attack', attack, 'defense', defense, 'power', totalpower) 
   # print(pokemon['name']) only give last player pokemon name
    return attack
    return defense
    return totalpower
            #return player
#print(player(players, pokedex, pokelist, 3))
print(power(players, pokedex, 5))
# Out:
# ('cia', 'attack', 188, 'defense', 8988, 'power', 29140)
# 188

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
import csv
raw_pd = ''
clean= []
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd =f.readlines()
    #raw_pd1= raw_pd[1:-1].split('","')
raw_pd
# Out:
# ['"PokedexNumber","Name","Type","Total","HP","Attack","Defense","SpecialAttack","SpecialDefense","Speed"\n',
#  '"001","Bulbasaur","GrassPoison","318","45","49","49","65","65","45"\n',
#  '"002","Ivysaur","GrassPoison","405","60","62","63","80","80","60"\n',
#  '"003","Venusaur","GrassPoison","525","80","82","83","100","100","80"\n',
#  '"003","VenusaurMega Venusaur","GrassPoison","625","80","100","123","122","120","80"\n',
#  '"004","Charmander","Fire","309","39","52","43","60","50","65"\n',
#  '"005","Charmeleon","Fire","405","58","64","58","80","65","80"\n',
#  '"006","Charizard","FireFlying","534","78","84","78","109","85","100"\n',
#  '"006","CharizardMega Charizard X","FireDragon","634","78","130","111","130","85","100"\n',
#  '"006","CharizardMega Charizard Y","FireFlying","634","78","104","78","159","115","100"\n',
#  '"007","Squirtle","Water","314","44","48","65","50","64","43"\n',
#  '"008","Wartortle","Water","405","59","63","80","65","80","58"\n',
# ...

# %%
#answer https://www.quora.com/How-can-I-iterate-a-CSV-file-using-a-list-of-distinct-elements-in-Python
a=open("pokedex_basic.csv","r")
ids=list(csv.reader(a,delimiter=","))
for i in ids:
    print(i)
 
with oprn (, 'rU')

row = []
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# ['001', 'Bulbasaur', 'GrassPoison', '318', '45', '49', '49', '65', '65', '45']
# ['002', 'Ivysaur', 'GrassPoison', '405', '60', '62', '63', '80', '80', '60']
# ['003', 'Venusaur', 'GrassPoison', '525', '80', '82', '83', '100', '100', '80']
# ['003', 'VenusaurMega Venusaur', 'GrassPoison', '625', '80', '100', '123', '122', '120', '80']
# ['004', 'Charmander', 'Fire', '309', '39', '52', '43', '60', '50', '65']
# ['005', 'Charmeleon', 'Fire', '405', '58', '64', '58', '80', '65', '80']
# ['006', 'Charizard', 'FireFlying', '534', '78', '84', '78', '109', '85', '100']
# ['006', 'CharizardMega Charizard X', 'FireDragon', '634', '78', '130', '111', '130', '85', '100']
# ['006', 'CharizardMega Charizard Y', 'FireFlying', '634', '78', '104', '78', '159', '115', '100']
# ['007', 'Squirtle', 'Water', '314', '44', '48', '65', '50', '64', '43']
# ...

# %% [markdown]
# def converter_helper(value):
#     try:
#         return float(value)
#     except:
#         return np.nan
#
# def convert_to_float(column):
#     column = column.map(converter_helper)
#     return column
# raw_pd.apply(convert_to_float)
#
# to convert to float

# %%
pokedex_basic_csv= 'pokedex_basic.csv'
pokedexbasic = pd.read_csv(pokedex_basic_csv)
pokedexbasic.head(8)
#pokedict=pokedexbasic.to_dict('index')
# Out:
#    PokedexNumber                       Name         Type  Total  HP  Attack  \
# 0              1                  Bulbasaur  GrassPoison    318  45      49
# 1              2                    Ivysaur  GrassPoison    405  60      62
# 2              3                   Venusaur  GrassPoison    525  80      82
# 3              3      VenusaurMega Venusaur  GrassPoison    625  80     100
# 4              4                 Charmander         Fire    309  39      52
# 5              5                 Charmeleon         Fire    405  58      64
# 6              6                  Charizard   FireFlying    534  78      84
# 7              6  CharizardMega Charizard X   FireDragon    634  78     130
#
#    Defense  SpecialAttack  SpecialDefense  Speed
# 0       49             65              65     45
# 1       63             80              80     60
# 2       83            100             100     80
# 3      123            122             120     80
# ...

# %%
#dsi-unit-1.09-python-descriptive_statistics_numpy-lab
#convert to float

#ayesha
#pokedexbasic.iloc[:, 2:] = pokedexbasic.iloc[:, 2:].astype(np.float64)
#from chao
Name=pokedexbasic['Name']
Type=pokedexbasic['Type']
Total=pokedexbasic[['Total']].astype(np.float32)
HP=pokedexbasic[['HP']].astype(np.float32)
Attack=pokedexbasic[['Attack']].astype(np.float32)
Defense=pokedexbasic[['Defense']].astype(np.float32)
SpecialAttack=pokedexbasic[['SpecialAttack']].astype(np.float32)
Speed=pokedexbasic[['Speed']].astype(np.float32)

#answers#
# please look in github Lab: Cleaning Rock Song Data
pokedexbasic.iloc[:, 3:] = pokedexbasic.iloc[:, 3:].astype(np.float64)

# %%
pokedexbasic.info()
#convert to float 
#for name, col in list(sales_data.items()):
#   col = [float(x) for x in col]
#  sales_data[name] = col
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 10 columns):
# PokedexNumber     800 non-null int64
# Name              800 non-null object
# Type              800 non-null object
# Total             800 non-null float64
# HP                800 non-null float64
# Attack            800 non-null float64
# Defense           800 non-null float64
# SpecialAttack     800 non-null float64
# SpecialDefense    800 non-null float64
# Speed             800 non-null float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 62.6+ KB

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
#poke_id= np.unique(pokedexbasic.PokedexNumber.values)
#poke_name = np.unique(pokedexbasic.Name.values)
#attribute = pd.DataFrame({'id':poke_id, 'Name': poke_name})
#poke_name= np.unique(pokedexbasic.Name.values)
#pokedexbasic.keys()
#print (attribute)
pokedict = pokedexbasic.to_dict('index')
pokedict[100]
# Out:
# {'Attack': 50,
#  'Defense': 45,
#  'HP': 45,
#  'Name': 'Haunter',
#  'PokedexNumber': 93,
#  'SpecialAttack': 115,
#  'SpecialDefense': 55,
#  'Speed': 95,
#  'Total': 405,
#  'Type': 'GhostPoison'}

# %%
pokedict= pokedexbasic.to_dict('index')
pokedexbasic
dic ={}
def pokedetail (pokedict,pid):
    for key in pokedict.keys():
        print ('PokedexNumber',pokedict[key]['PokedexNumber'],pokedict[key]['Name'],pokedict[key]['Type'],pokedict[key]['Total'],pokedict[key]['Attack'],pokedict[key]['Speed'], pokedict[key]['SpecialAttack'],pokedict[key]['HP'],pokedict[key]['SpecialDefense'], pokedict[key]['Defense']) #manymore
        
    return (pokedetail)
   
print(pokedetail(pokedict, 1))
# Out:
# ('PokedexNumber', 1, 'Bulbasaur', 'GrassPoison', 318, 49, 45, 65, 45, 65, 49)
# ('PokedexNumber', 2, 'Ivysaur', 'GrassPoison', 405, 62, 60, 80, 60, 80, 63)
# ('PokedexNumber', 3, 'Venusaur', 'GrassPoison', 525, 82, 80, 100, 80, 100, 83)
# ('PokedexNumber', 3, 'VenusaurMega Venusaur', 'GrassPoison', 625, 100, 80, 122, 80, 120, 123)
# ('PokedexNumber', 4, 'Charmander', 'Fire', 309, 52, 65, 60, 39, 50, 43)
# ('PokedexNumber', 5, 'Charmeleon', 'Fire', 405, 64, 80, 80, 58, 65, 58)
# ('PokedexNumber', 6, 'Charizard', 'FireFlying', 534, 84, 100, 109, 78, 85, 78)
# ('PokedexNumber', 6, 'CharizardMega Charizard X', 'FireDragon', 634, 130, 100, 130, 78, 85, 111)
# ('PokedexNumber', 6, 'CharizardMega Charizard Y', 'FireFlying', 634, 104, 100, 159, 78, 115, 78)
# ('PokedexNumber', 7, 'Squirtle', 'Water', 314, 48, 43, 50, 44, 64, 65)
# ('PokedexNumber', 8, 'Wartortle', 'Water', 405, 63, 58, 65, 59, 80, 80)
# ('PokedexNumber', 9, 'Blastoise', 'Water', 530, 83, 78, 85, 79, 105, 100)
# ...

# %% [markdown]
# def name (dataframe):
#     q={}
#     for row is range (0, len(dataframe)):
#         row .loc(row,:)
#         key= poke number
#         q[key]= value
#
#
# PokedexNumber	Name	Type	Total	HP	Attack	Defense	SpecialAttack	SpecialDefense	Speed

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```
# #List Comprehensions Independent Practice 1.06

# %% [markdown]
# def filtered (a,b,c):
#     for values in pokevalues:
#         if values['Attack']> a and values['Defense']> b and values['Type']== c:
#             print ('Attack',values['Attack'],'Defense',values['Defense'], 'Type',values['Type'])
#     return filtered
# print (filtered(10,50,'Electric'))

# %%
poke=pokedexbasic.to_dict('index')
pokevalues =poke.values()
pokevalues
def filtered (a,b,c):
    for values in pokevalues:
        if values['Attack']> a and values['Defense']> b and values['Type']== c:
            print('Attack',values['Attack'],
                  'Defense',values['Defense'], 
                  'HP',values['HP'],
                  'Name',values['Name'],
                  'SpecialAttack',values['SpecialAttack'],
                  'SpecialDefense',values['SpecialDefense'],
                  'Speed',values['Speed'],
                  'Total',values['Total'],
                  'Type',values['Type'],
                 )
    return filtered
print (filtered(88,22,'Electric'))
# Out:
# ('Attack', 90, 'Defense', 55, 'HP', 60, 'Name', 'Raichu', 'SpecialAttack', 90, 'SpecialDefense', 80, 'Speed', 110, 'Total', 485, 'Type', 'Electric')
# ('Attack', 120, 'Defense', 79, 'HP', 80, 'Name', 'Luxray', 'SpecialAttack', 95, 'SpecialDefense', 79, 'Speed', 70, 'Total', 523, 'Type', 'Electric')
# ('Attack', 123, 'Defense', 67, 'HP', 75, 'Name', 'Electivire', 'SpecialAttack', 95, 'SpecialDefense', 85, 'Speed', 95, 'Total', 540, 'Type', 'Electric')
# ('Attack', 100, 'Defense', 63, 'HP', 75, 'Name', 'Zebstrika', 'SpecialAttack', 80, 'SpecialDefense', 63, 'Speed', 116, 'Total', 497, 'Type', 'Electric')
# ('Attack', 115, 'Defense', 80, 'HP', 85, 'Name', 'Eelektross', 'SpecialAttack', 105, 'SpecialDefense', 80, 'Speed', 50, 'Total', 515, 'Type', 'Electric')
# <function filtered at 0x119507cf8>

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
# %matplotlib inline
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mean =pokedexbasic['Total'].mean()
std = pokedexbasic['Total'].std()
over =(mean +std*3)
median =pokedexbasic['Total'].median()
std
#=====#or#
mean =np.mean(pokedexbasic['Total'])
std =np.std(pokedexbasic['Total'])
#=====#or
pokedexbasic.describe()
# Out:
#        PokedexNumber       Total          HP      Attack     Defense  \
# count     800.000000  800.000000  800.000000  800.000000  800.000000
# mean      362.813750  435.127500   69.283750   79.001250   73.842500
# std       208.343798  120.037067   25.580436   32.457366   31.183501
# min         1.000000  180.000000    1.000000    5.000000    5.000000
# 25%       184.750000  330.000000   50.000000   55.000000   50.000000
# 50%       364.500000  450.000000   65.000000   75.000000   70.000000
# 75%       539.250000  515.000000   80.000000  100.000000   90.000000
# max       721.000000  800.000000  255.000000  190.000000  230.000000
#
#        SpecialAttack  SpecialDefense       Speed
# count     800.000000      800.000000  800.000000
# mean       72.820000       71.902500   68.277500
# std        32.722294       27.828916   29.060474
# min        10.000000       20.000000    5.000000
# 25%        49.750000       50.000000   45.000000
# ...

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
over =(mean +std*3)
for v in pokedexbasic['Total']:
    if v >=over:
        print (v)
        
        #so there is 1
# Out:
# 800

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.
#
# #dsi-unit-1.08-Python-descriptive_statistics_numpy-lessonsolution-code

# %%
#mywork
p  =sum(pokedexbasic['Total'])/len(pokedexbasic['Total'])
minimum = pokedexbasic['Total'].min()
maximum = pokedexbasic['Total'].max()
mean =pokedexbasic['Total'].mean()
std = pokedexbasic['Total'].std()
over =(mean +std*3)
median =pokedexbasic['Total'].median()
mode = stats.mode(pokedexbasic['Total'])

print('mean', mean, 'std', std,'median', median, 'minimum',minimum,'maximum',maximum,'mode',mode)
#def skeweness
def skewness(lis):
    if np.mean(lis) > np.median(lis):
        print("The data is skewed right")
    elif np.mean(lis) < np.median(lis):
        print("The data is skewed left")
    else:
        print("The data is normally distributed")
    
skewness(pokedexbasic['Total'])

# range =space between the lowest and highest values
sorted_pokedexbasic = sorted(pokedexbasic['Total'])
print(sorted_pokedexbasic[-1] - sorted_pokedexbasic[0])

#variance
variance = np.var(pokedexbasic['Total'])
print(variance)

pokedexbasic['Total'].hist(bins=10)
# Out:
# ('mean', 435.1275, 'std', 120.03706663134037, 'median', 450.0, 'minimum', 180, 'maximum', 800, 'mode', ModeResult(mode=array([600]), count=array([37])))
# The data is skewed left
# 620
# 14390.8862438

# %%
#get probability each total/ number of data
probability =pokedexbasic['Total']/len(pokedexbasic['Total'])
probability

#reverse the order of probability
reverseprobability =probability.iloc[::-1]
newrevese =1-reverseprobability

#add dataframe
pokedexbasic['probability'] = newrevese

#do the graph
plt.plot(pokedexbasic['Total'], pokedexbasic['probability'])
plt.show()

# %%
#Write a function that takes in a Pokedex number and returns a value  pi for that character.
pokedexprobability=pokedexbasic.to_dict('index')
pokevalues =pokedexprobability.values()
listp=list(pokedexbasic.to_dict('index'))
pokevalues.append(listp)

#if pokevalues['PokedexNumber']== 1:
 #   print (pokevalues)
#for poke in pokedexprobability:
 #   for values in pokevalues:
  ##         print (values)
def probilityvalues (pokevalues, pokenum):
    for values in pokevalues:
        if values['PokedexNumber'] == pokenum:
            print('PokedexNumber', values ['PokedexNumber'],'probability',values ['probability'] )
            return probilityvalues
print (probilityvalues (pokevalues,3))
# Out:
# ('PokedexNumber', 3, 'probability', 0.34375)
# <function probilityvalues at 0x1a1f8a2668>

# %%
pokedexbasic[pokedexbasic.PokedexNumber==1]
#if PokedexNumber[pokedexbasic.PokedexNumber==1]:
#PokedexNumber[pokedexbasic.probability
# Out:
#    PokedexNumber       Name         Type  Total  HP  Attack  Defense  \
# 0              1  Bulbasaur  GrassPoison    318  45      49       49
#
#    SpecialAttack  SpecialDefense  Speed  probability
# 0             65              65     45       0.6025
